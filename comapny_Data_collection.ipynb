# %% [markdown]
# <a href="https://colab.research.google.com/github/DHARMADEVIKEERTHI/Company-Data-Analysis/blob/main/comapny_Data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
np.set_printoptions(threshold=np.inf)

# %%
df = pd.read_csv('/content/DA - Test Sheet - Company Inputs - Sheet1 (1).csv')
df.head()
# Out:
#           Company Name         Person Name  \
# 0            BO Street      Kunal Abhishek
# 1  Logiclens Solutions       Ajay Satpathy
# 2   Adloop Innovations  Karthik Rajendiran
# 3             Kimipost      Rajesh Singhal
# 4           Spacempact         Niyati Shah
#
#                                                                   Designation  \
# 0                                                                  Co-Founder
# 1                                                             Founder and CEO
# 2                                                    Chief Technology Officer
# 3  Co-Founder @ Kimipost "Empowering eCommerce Shipping with Tech Automation"
# 4                                                                  Co-Founder
#
#                                           Person Linkedin Unnamed: 4  \
# 0                http://www.linkedin.com/in/kunalabhishek        NaN
# 1      http://www.linkedin.com/in/ajay-satpathy-6a939516a        NaN
# ...

# %%
Company_input = df.copy

# %%
df.shape
# Out:
# (31680, 7)

# %%
df.columns
# Out:
# Index(['Company Name', 'Person Name', 'Designation', 'Person Linkedin',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31680 entries, 0 to 31679
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company Name     31679 non-null  object
#  1   Person Name      31679 non-null  object
#  2   Designation      31679 non-null  object
#  3   Person Linkedin  31676 non-null  object
#  4   Unnamed: 4       2 non-null      object
#  5   Unnamed: 5       0 non-null      float64
#  6   Unnamed: 6       5 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# Company Name           1
# Person Name            1
# Designation            1
# Person Linkedin        4
# Unnamed: 4         31678
# Unnamed: 5         31680
# Unnamed: 6         31675
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(10983)

# %%
df.describe()
# Out:
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.isnull().sum() / len(df)* 100
# Out:
# Company Name         0.003157
# Person Name          0.003157
# Designation          0.003157
# Person Linkedin      0.012626
# Unnamed: 4          99.993687
# Unnamed: 5         100.000000
# Unnamed: 6          99.984217
# dtype: float64

# %%
df.drop(columns=['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'], inplace=True)

# %%
df.columns
# Out:
# Index(['Company Name', 'Person Name', 'Designation', 'Person Linkedin'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31680 entries, 0 to 31679
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company Name     31679 non-null  object
#  1   Person Name      31679 non-null  object
#  2   Designation      31679 non-null  object
#  3   Person Linkedin  31676 non-null  object
# dtypes: object(4)
# memory usage: 990.1+ KB

# %%
df.isnull().sum()
# Out:
# Company Name       1
# Person Name        1
# Designation        1
# Person Linkedin    4
# dtype: int64

# %%
df.isnull().sum() / len(df)* 100
# Out:
# Company Name       0.003157
# Person Name        0.003157
# Designation        0.003157
# Person Linkedin    0.012626
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Company Name       0
# Person Name        0
# Designation        0
# Person Linkedin    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(10987)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (20689, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20689 entries, 0 to 31670
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company Name     20689 non-null  object
#  1   Person Name      20689 non-null  object
#  2   Designation      20689 non-null  object
#  3   Person Linkedin  20689 non-null  object
# dtypes: object(4)
# memory usage: 808.2+ KB

# %%
df.to_csv("company input.csv", index=False)

# %%
df1 = pd.read_csv("/content/DA - Test - Company Inputs 2 - Overall Company List  (1).csv")
df1.head()
# Out:
#   Founded Year                          Company # Employees  \
# 0         1528  Birbal Learning Private Limited          19
# 1         1771                   Thewastore.com           2
# 2         1850  Northfield Township of Illinois          11
# 3         1853   City of Lawrence Massachusetts           6
# 4         1865                           epilot          59
#
#                              Website                           Industry  \
# 0           http://www.birbal.org.in  information technology & services
# 1          http://www.thewastore.com                      arts & crafts
# 2  http://www.northfieldtownship.com          government administration
# 3      http://www.cityoflawrence.com                                NaN
# 4         http://www.pilotonline.com                   media production
#
# ...

# %%
company_input_2 = df1.copy

# %%
df1.shape
# Out:
# (21264, 11)

# %%
df1.columns
# Out:
# Index(['Founded Year', 'Company', '# Employees', 'Website', 'Industry',
#        'Keywords', 'SEO Description', 'Latest Funding type',
#        'Latest Funding Amount', 'Last Raised At', 'Annual Revenue'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21264 entries, 0 to 21263
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Founded Year           18756 non-null  object
#  1   Company                21264 non-null  object
#  2   # Employees            21264 non-null  object
#  3   Website                21186 non-null  object
#  4   Industry               20363 non-null  object
#  5   Keywords               12854 non-null  object
#  6   SEO Description        10627 non-null  object
#  7   Latest Funding type    3944 non-null   object
#  8   Latest Funding Amount  3471 non-null   object
#  9   Last Raised At         3944 non-null   object
#  10  Annual Revenue         3850 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 1.8+ MB

# %%
df1.describe(include='all')
# Out:
#        Founded Year Company # Employees                    Website  \
# count         18756   21264       21264                      21186
# unique          659   21208         110                      21137
# top            2020  Spare8           2  http://www.ibilglobal.com
# freq           1717       2        1237                          2
# mean            NaN     NaN         NaN                        NaN
# std             NaN     NaN         NaN                        NaN
# min             NaN     NaN         NaN                        NaN
# 25%             NaN     NaN         NaN                        NaN
# 50%             NaN     NaN         NaN                        NaN
# 75%             NaN     NaN         NaN                        NaN
# max             NaN     NaN         NaN                        NaN
#
#                                  Industry              Keywords  \
# count                               20363                 12854
# ...

# %%
df1.isnull().sum()
# Out:
# Founded Year              2508
# Company                      0
# # Employees                  0
# Website                     78
# Industry                   901
# Keywords                  8410
# SEO Description          10637
# Latest Funding type      17320
# Latest Funding Amount    17793
# Last Raised At           17320
# Annual Revenue           17414
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(6)

# %%
df1.isnull().sum() / len(df)* 100
# Out:
# Founded Year             12.122384
# Company                   0.000000
# # Employees               0.000000
# Website                   0.377012
# Industry                  4.354971
# Keywords                 40.649621
# SEO Description          51.413795
# Latest Funding type      83.715984
# Latest Funding Amount    86.002223
# Last Raised At           83.715984
# Annual Revenue           84.170332
# dtype: float64

# %%
df1.rename(columns={"# Employees": "Employees"}, inplace=True)

# %%
df1.columns
# Out:
# Index(['Founded Year', 'Company', 'Employees', 'Website', 'Industry',
#        'Keywords', 'SEO Description', 'Latest Funding type',
#        'Latest Funding Amount', 'Last Raised At', 'Annual Revenue'],
#       dtype='object')

# %%
df1["Founded Year"] = df1["Founded Year"].astype(str).str.extract(r"(\d{4})")

# %%
df1.tail()
# Out:
#       Founded Year           Company Employees                  Website  \
# 21259         2025     Atma Sciences      1-10                 atma.inc
# 21260         2025             FEESH      1-10                      NaN
# 21261          NaN     UFarm.Digital         —            ufarm.digital
# 21262         1905  Yourway Learning     11-50  www.yourwaylearning.com
# 21263         1905             Otaxi         —                 otaxi.om
#
#                             Industry Keywords SEO Description  \
# 21259                            NaN      NaN             NaN
# 21260        Agriculture and Farming      NaN             NaN
# 21261  Blockchain and Cryptocurrency      NaN             NaN
# 21262   Artificial Intelligence (AI)      NaN             NaN
# 21263                 Transportation      NaN             NaN
#
#       Latest Funding type Latest Funding Amount Last Raised At  Annual Revenue
# 21259                Seed            $5,487,480    Feb 1, 2025             NaN
# ...

# %%
columns_to_drop = ['Latest Funding type', 'Latest Funding Amount', 'Last Raised At', 'Annual Revenue']
df1.drop(columns=columns_to_drop, inplace=True)

# %%
df1.head()
# Out:
#   Founded Year                          Company Employees  \
# 0         1528  Birbal Learning Private Limited        19
# 1         1771                   Thewastore.com         2
# 2         1850  Northfield Township of Illinois        11
# 3         1853   City of Lawrence Massachusetts         6
# 4         1865                           epilot        59
#
#                              Website                           Industry  \
# 0           http://www.birbal.org.in  information technology & services
# 1          http://www.thewastore.com                      arts & crafts
# 2  http://www.northfieldtownship.com          government administration
# 3      http://www.cityoflawrence.com                                NaN
# 4         http://www.pilotonline.com                   media production
#
# ...

# %%
df1.columns
# Out:
# Index(['Founded Year', 'Company', 'Employees', 'Website', 'Industry',
#        'Keywords', 'SEO Description'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# Founded Year        2600
# Company                0
# Employees              0
# Website               78
# Industry             901
# Keywords            8410
# SEO Description    10637
# dtype: int64

# %%
df1['Founded Year'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-298-710cfa5f9301>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Founded Year'].fillna(method='ffill', inplace=True)
# <ipython-input-298-710cfa5f9301>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['Founded Year'].fillna(method='ffill', inplace=True)

# %%
df1.isnull().sum()
# Out:
# Founded Year           0
# Company                0
# Employees              0
# Website               78
# Industry             901
# Keywords            8410
# SEO Description    10637
# dtype: int64

# %%
df1.shape
# Out:
# (21264, 7)

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# Founded Year       0
# Company            0
# Employees          0
# Website            0
# Industry           0
# Keywords           0
# SEO Description    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7241 entries, 2 to 19490
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Founded Year     7241 non-null   object
#  1   Company          7241 non-null   object
#  2   Employees        7241 non-null   object
#  3   Website          7241 non-null   object
#  4   Industry         7241 non-null   object
#  5   Keywords         7241 non-null   object
#  6   SEO Description  7241 non-null   object
# dtypes: object(7)
# memory usage: 452.6+ KB

# %%
df1['Founded Year'] = pd.to_numeric(df1['Founded Year'], errors='coerce')
df1['Employees'] = pd.to_numeric(df1['Employees'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7241 entries, 2 to 19490
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Founded Year     7241 non-null   int64
#  1   Company          7241 non-null   object
#  2   Employees        7241 non-null   int64
#  3   Website          7241 non-null   object
#  4   Industry         7241 non-null   object
#  5   Keywords         7241 non-null   object
#  6   SEO Description  7241 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 452.6+ KB

# %%
df1.to_csv("company_input_2.csv" ,index=False)

# %%
df2 = pd.read_csv("/content/DA - Test - Company List 3 - FundInputs (1).csv")
df2.head()
# Out:
#          Company Name   Funded Date   Funded Amount                 Fund Type  \
# 0             Pure EV  Feb 19, 2024  â‚¹660,000,000                  Series A
# 1               Haber  Dec 11, 2024      $6,000,000            Debt Financing
# 2    Scrut Automation   Apr 2, 2024     $10,000,000            Private Equity
# 3  Orange Health Labs   Dec 6, 2024     $12,000,000  Venture - Series Unknown
# 4              Bhanzu  Nov 11, 2024     $16,500,000                  Series B
#
#                                   Company Linkedin Url             Website   \
# 0         https://www.linkedin.com/company/pureevindia        www.pureev.in
# 1  https://www.linkedin.com/company/haber-technologies   www.haberwater.com
# 2    https://www.linkedin.com/company/scrut-automation         www.scrut.io
# 3       https://www.linkedin.com/company/orange-health  www.orangehealth.in
# 4              https://www.linkedin.com/company/bhanzu           bhanzu.com
#
# ...

# %%
company_list_3 = df2.copy

# %%
df2.shape
# Out:
# (17773, 11)

# %%
df2.columns
# Out:
# Index(['Company Name', 'Funded Date', 'Funded Amount', 'Fund Type',
#        'Company Linkedin Url', 'Website ', 'No.of Emp', 'Industries',
#        'No.of Decision Makers', 'Priority', 'Founded Year'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17773 entries, 0 to 17772
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Company Name           17768 non-null  object
#  1   Funded Date            14778 non-null  object
#  2   Funded Amount          14410 non-null  object
#  3   Fund Type              14485 non-null  object
#  4   Company Linkedin Url   15478 non-null  object
#  5   Website                12030 non-null  object
#  6   No.of Emp              6661 non-null   object
#  7   Industries             8792 non-null   object
#  8   No.of Decision Makers  5243 non-null   object
#  9   Priority               1782 non-null   object
#  10  Founded Year           1758 non-null   object
# dtypes: object(11)
# memory usage: 1.5+ MB

# %%
df2.isnull().sum()
# Out:
# Company Name                 5
# Funded Date               2995
# Funded Amount             3363
# Fund Type                 3288
# Company Linkedin Url      2295
# Website                   5743
# No.of Emp                11112
# Industries                8981
# No.of Decision Makers    12530
# Priority                 15991
# Founded Year             16015
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# np.int64(85)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.shape
# Out:
# (17688, 11)

# %%
df2.describe(include="all")
# Out:
#        Company Name Funded Date Funded Amount Fund Type  \
# count         17683       14694         14326     14401
# unique        12837        2236          1984      1563
# top       YardHotel           —             —      Seed
# freq             10        3491          6816      5024
#
#                              Company Linkedin Url Website  No.of Emp  \
# count                                       15408    11946      6651
# unique                                      11000     8023        26
# top     https://www.linkedin.com/company/biva-ai/  biva.ai     11-50
# freq                                           10        9      4428
#
#        Industries No.of Decision Makers Priority Founded Year
# count        8766                  5234     1743         1758
# unique       2313                     7        2          468
# top            AI                     —       P1         2020
# freq         2923                  2096     1081          438

# %%
df2.isnull().sum() / len(df2)* 100
# Out:
# Company Name              0.028268
# Funded Date              16.926730
# Funded Amount            19.007237
# Fund Type                18.583220
# Company Linkedin Url     12.890095
# Website                  32.462687
# No.of Emp                62.398236
# Industries               50.440977
# No.of Decision Makers    70.409317
# Priority                 90.145862
# Founded Year             90.061058
# dtype: float64

# %%
columns_to_drop = ['No.of Emp','No.of Decision Makers', 'Priority', 'Founded Year']
df2.drop(columns=columns_to_drop, inplace=True)

# %%
df2.head()
# Out:
#          Company Name   Funded Date   Funded Amount                 Fund Type  \
# 0             Pure EV  Feb 19, 2024  â‚¹660,000,000                  Series A
# 1               Haber  Dec 11, 2024      $6,000,000            Debt Financing
# 2    Scrut Automation   Apr 2, 2024     $10,000,000            Private Equity
# 3  Orange Health Labs   Dec 6, 2024     $12,000,000  Venture - Series Unknown
# 4              Bhanzu  Nov 11, 2024     $16,500,000                  Series B
#
#                                   Company Linkedin Url             Website   \
# 0         https://www.linkedin.com/company/pureevindia        www.pureev.in
# 1  https://www.linkedin.com/company/haber-technologies   www.haberwater.com
# 2    https://www.linkedin.com/company/scrut-automation         www.scrut.io
# 3       https://www.linkedin.com/company/orange-health  www.orangehealth.in
# 4              https://www.linkedin.com/company/bhanzu           bhanzu.com
#
#   Industries
# 0        NaN
# ...

# %%
df2.columns
# Out:
# Index(['Company Name', 'Funded Date', 'Funded Amount', 'Fund Type',
#        'Company Linkedin Url', 'Website ', 'Industries'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17688 entries, 0 to 17772
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company Name          17683 non-null  object
#  1   Funded Date           14694 non-null  object
#  2   Funded Amount         14326 non-null  object
#  3   Fund Type             14401 non-null  object
#  4   Company Linkedin Url  15408 non-null  object
#  5   Website               11946 non-null  object
#  6   Industries            8766 non-null   object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %%
df2.isnull().sum()
# Out:
# Company Name               5
# Funded Date             2994
# Funded Amount           3362
# Fund Type               3287
# Company Linkedin Url    2280
# Website                 5742
# Industries              8922
# dtype: int64

# %%
df2.isnull().sum() / len(df2)* 100
# Out:
# Company Name             0.028268
# Funded Date             16.926730
# Funded Amount           19.007237
# Fund Type               18.583220
# Company Linkedin Url    12.890095
# Website                 32.462687
# Industries              50.440977
# dtype: float64

# %%
df2['Funded Date'] = df2['Funded Date'].replace({'â€”': None, 'Ã¢â‚¬â€': None, '-': None})

df2['Funded Date'] = pd.to_datetime(df2['Funded Date'], errors='coerce')

# %%
df2['Funded Date'].unique()
# Out:
# <DatetimeArray>
# ['2024-02-19 00:00:00', '2024-12-11 00:00:00', '2024-04-02 00:00:00',
#  '2024-12-06 00:00:00', '2024-11-11 00:00:00', '2024-06-11 00:00:00',
#  '2024-04-18 00:00:00', '2024-02-27 00:00:00', '2024-09-24 00:00:00',
#  '2024-10-15 00:00:00',
#  ...
#  '2022-10-14 00:00:00', '2021-02-17 00:00:00', '2020-03-30 00:00:00',
#  '2020-02-28 00:00:00', '2020-02-08 00:00:00', '2022-07-03 00:00:00',
#  '2020-06-20 00:00:00', '2020-01-29 00:00:00', '2020-09-16 00:00:00',
#  '2021-08-22 00:00:00']
# Length: 1444, dtype: datetime64[ns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17688 entries, 0 to 17772
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company Name          17683 non-null  object
#  1   Funded Date           5529 non-null   datetime64[ns]
#  2   Funded Amount         14326 non-null  object
#  3   Fund Type             14401 non-null  object
#  4   Company Linkedin Url  15408 non-null  object
#  5   Website               11946 non-null  object
#  6   Industries            8766 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 1.1+ MB

# %%
df2['Funded Amount'] = df2['Funded Amount'].replace(r'[^\d]', '', regex=True)

# %%
df2['Funded Amount'].unique()
# Out:
# array(['660000000', '6000000', '10000000', '12000000', '16500000',
#        '65000000', '155400000', '334000000', '200000000', '330000000', '',
#        '300000000', '386400000', '900000000', '783000000', '1510000000',
#        '2650000000', '30000000', '1500000000', '281000000', '9500000',
#        '4750000', '122500000', '27500000', '270000000', '20000000',
#        '1000000000', '240000000', '24500000', '695000000', '275000000',
#        '880000000', '826000000', '74000000', '3500000', '17300000',
#        '3100000000', '1100000000', '1750000000', '8000000', '920000000',
#        '110000000', '2000000', '3000000', '820000000', '450000000',
#        '163000000', '373000000', '1155000000', '13000000', '750000000',
#        '123000000', '1400000000', '700000000', '328000000', '184000000',
#        '84000000', '535000000', '4000000', '1120000000', '500000000',
#        '1501600000', '207800000', '599000000', '600000000', '1600000000',
# ...

# %%
df2['Fund Type'] = df2['Fund Type'].replace({'â€”': None, 'Ã¢â‚¬â€': None, '-': None})

# %%
df2['Fund Type'].unique()
# Out:
# array(['Series A', 'Debt Financing', 'Private Equity',
#        'Venture - Series Unknown', 'Series B', 'Seed', 'Series D',
#        'Series C', None, 'Angel', 'Pre-Seed', 'Non-equity Assistance',
#        'Convertible Note', 'Secondary Market', 'Undisclosed', 'Grant',
#        'Corporate Round', 'Equity Crowdfunding', 'Series E', '—',
#        'Post-IPO Debt', 'Post-IPO Equity', 'Pre Seed',
#        'Seed Round - Spice World Ventures Inc',
#        'Post-IPO Equity - Pitti Engineering', nan,
#        'Grant - Rochester Institute of Technology',
#        'Post-IPO Secondary - Jyoti CNC Automation',
#        'Post-IPO Debt - Eastman Chemical Company', 'Post-IPO Secondary',
#        'Series F', 'Grant - National Football League',
#        'Post-IPO Debt - Host Hotels & Resorts',
#        'Private Equity Round - Beyond Law Group',
#        'Grant - Wyss Institute',
#        'Grant - Georgia Institute of Technology', 'Funding Round',
# ...

# %%
df2['Company Linkedin Url'] = df2['Company Linkedin Url'].apply(lambda x: np.nan if isinstance(x, (int, float)) else x)

# %%
df2['Company Linkedin Url'].unique()
# Out:
# array(['https://www.linkedin.com/company/pureevindia',
#        'https://www.linkedin.com/company/haber-technologies',
#        'https://www.linkedin.com/company/scrut-automation',
#        'https://www.linkedin.com/company/orange-health',
#        'https://www.linkedin.com/company/bhanzu',
#        'https://www.linkedin.com/company/batterysmart',
#        'https://www.linkedin.com/company/uniqus-consultech',
#        'https://www.linkedin.com/company/digantara/',
#        'https://www.linkedin.com/company/corover',
#        'https://www.linkedin.com/company/the-good-bug',
#        'https://www.linkedin.com/company/billion-hearts-software-technologies',
#        'https://www.linkedin.com/company/satsure',
#        'https://www.linkedin.com/company/credable.in',
#        'https://www.linkedin.com/company/money-view/',
#        'https://linkedin.com/company/ecofyfinance',
#        'https://www.linkedin.com/company/astrotalk-online-astrology-predictions/',
# ...

# %%
df2['Website '].unique()
# Out:
# array(['www.pureev.in', 'www.haberwater.com', 'www.scrut.io',
#        'www.orangehealth.in', 'bhanzu.com', 'www.batterysmart.in',
#        'www.uniqus.com', 'www.digantara.co.in/', 'CoRover.ai',
#        'thegoodbug.com', 'www.billionhearts.co', 'satsure.co',
#        'www.credable.in', 'moneyview.in', 'www.ecofy.co.in',
#        'astrotalk.com/', 'appsforbharat.com', 'www.dezerv.in',
#        'solinas.in', 'qure.ai', 'even.in', 'www.vidyuttech.com/',
#        'www.globalbees.com/', 'abcoffee.in', 'www.scimplifi.com',
#        'finarkein.com', 'skininspired.in', 'www.nurix.ai', 'yoholife.in',
#        'www.sprinto.com', 'www.lendingkart.com', 'ecozensolutions.com',
#        'www.awign.com', 'www.lissun.app/', 'www.bighaat.com',
#        'fourthpartner.co', 'pandorum.com', 'matter.in',
#        'www.getonecard.app/', 'foxtale.in/', 'www.techjockey.com/',
#        'www.genwise.club/', 'droom.in/', 'www.agrim.app',
#        'www.vridhihomefinance.com', 'recykal.com/',
# ...

# %%
df2.columns
# Out:
# Index(['Company Name', 'Funded Date', 'Funded Amount', 'Fund Type',
#        'Company Linkedin Url', 'Website ', 'Industries'],
#       dtype='object')

# %%
df2 = df2.rename(columns={'Website ': 'Website'})

# %%
df2['Website'] = df2['Website'].apply(lambda x: f"https://{x}" if isinstance(x, str) and not x.startswith(('http://', 'https://')) else x)

# %%
df2['Website'].unique()
# Out:
# array(['https://www.pureev.in', 'https://www.haberwater.com',
#        'https://www.scrut.io', 'https://www.orangehealth.in',
#        'https://bhanzu.com', 'https://www.batterysmart.in',
#        'https://www.uniqus.com', 'https://www.digantara.co.in/',
#        'https://CoRover.ai', 'https://thegoodbug.com',
#        'https://www.billionhearts.co', 'https://satsure.co',
#        'https://www.credable.in', 'https://moneyview.in',
#        'https://www.ecofy.co.in', 'https://astrotalk.com/',
#        'https://appsforbharat.com', 'https://www.dezerv.in',
#        'https://solinas.in', 'https://qure.ai', 'https://even.in',
#        'https://www.vidyuttech.com/', 'https://www.globalbees.com/',
#        'https://abcoffee.in', 'https://www.scimplifi.com',
#        'https://finarkein.com', 'https://skininspired.in',
#        'https://www.nurix.ai', 'https://yoholife.in',
#        'https://www.sprinto.com', 'https://www.lendingkart.com',
# ...

# %%
df2.isnull().sum()
# Out:
# Company Name                5
# Funded Date             12159
# Funded Amount            3362
# Fund Type                3303
# Company Linkedin Url     2280
# Website                  5742
# Industries               8922
# dtype: int64

# %%
df2.isnull().sum() / len(df2)* 100
# Out:
# Company Name             0.028268
# Funded Date             68.741520
# Funded Amount           19.007237
# Fund Type               18.673677
# Company Linkedin Url    12.890095
# Website                 32.462687
# Industries              50.440977
# dtype: float64

# %%
df2['Funded Date'] = df2['Funded Date'].fillna(method='ffill')
# Out:
# <ipython-input-341-89e6820d51d7>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2['Funded Date'] = df2['Funded Date'].fillna(method='ffill')

# %%
df2.isnull().sum()
# Out:
# Company Name               5
# Funded Date                0
# Funded Amount           3362
# Fund Type               3303
# Company Linkedin Url    2280
# Website                 5742
# Industries              8922
# dtype: int64

# %%
df2['Website'] = df2.groupby('Company Name')['Website'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else np.nan))
# Out:
# <ipython-input-344-3845f33ec0ce>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Website'] = df2.groupby('Company Name')['Website'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else np.nan))

# %%
df2.isnull().sum()
# Out:
# Company Name               5
# Funded Date                0
# Funded Amount           3362
# Fund Type               3303
# Company Linkedin Url    2280
# Website                 5434
# Industries              8922
# dtype: int64

# %%
df2['Industries'].fillna(df2['Industries'].mode()[0], inplace=True)
# Out:
# <ipython-input-346-ccb2d59ca6d0>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Industries'].fillna(df2['Industries'].mode()[0], inplace=True)

# %%
df2.isnull().sum()
# Out:
# Company Name               5
# Funded Date                0
# Funded Amount           3362
# Fund Type               3303
# Company Linkedin Url    2280
# Website                 5434
# Industries                 0
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# Company Name            0
# Funded Date             0
# Funded Amount           0
# Fund Type               0
# Company Linkedin Url    0
# Website                 0
# Industries              0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# np.int64(235)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10723 entries, 0 to 16011
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company Name          10723 non-null  object
#  1   Funded Date           10723 non-null  datetime64[ns]
#  2   Funded Amount         10723 non-null  object
#  3   Fund Type             10723 non-null  object
#  4   Company Linkedin Url  10723 non-null  object
#  5   Website               10723 non-null  object
#  6   Industries            10723 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 670.2+ KB

# %%
df2.to_csv("company_list_3.csv", index=False)

# %%
df3 = pd.read_csv("/content/DA - Test - Email Campaign Process - All Email Data (1).csv")
df3.head()
# Out:
#   Company Name                  Name              Tittle  \
# 0        50Fin          Darpan Tanna          Co-Founder
# 1        8club            Madhur Rao  Co-Founder and CTO
# 2        8club       Kaushal Chanani          Co-Founder
# 3        8club           Kunal Yadav    Co-Founder & CEO
# 4       AADYAH  Sunderarajan Varadan                 CEO
#
#                    Website  \
# 0    https://www.50fin.in/
# 1    https://www.8club.co/
# 2    https://www.8club.co/
# 3    https://www.8club.co/
# 4  https://www.aadyah.com/
#
#                                                    Company Linkedin   \
# 0                             https://www.linkedin.com/company/50fin
# 1                        https://www.linkedin.com/company/eight.club
# 2                        https://www.linkedin.com/company/eight.club
# 3                        https://www.linkedin.com/company/eight.club
# 4  https://www.linkedin.com/company/aadyah-aerospace-private-limited
#
# ...

# %%
All_Email_Data = df3.copy

# %%
df3.shape
# Out:
# (9893, 8)

# %%
df3.columns
# Out:
# Index(['Company Name', 'Name', 'Tittle', 'Website', 'Company Linkedin ',
#        'Linkedin URL', 'Campaign Name', 'Email Status'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9893 entries, 0 to 9892
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company Name       9893 non-null   object
#  1   Name               9893 non-null   object
#  2   Tittle             9893 non-null   object
#  3   Website            3686 non-null   object
#  4   Company Linkedin   3656 non-null   object
#  5   Linkedin URL       8064 non-null   object
#  6   Campaign Name      6045 non-null   object
#  7   Email Status       3775 non-null   object
# dtypes: object(8)
# memory usage: 618.4+ KB

# %%
df3.describe(include='all')
# Out:
#         Company Name          Name      Tittle Website Company Linkedin   \
# count           9893          9893        9893    3686              3656
# unique          3416          5875        1290    2148              1899
# top     Tata Capital  Mayank Gupta  Co-Founder   #REF!             #REF!
# freq              21            13        2314      72                72
#
#                                           Linkedin URL  \
# count                                             8064
# unique                                            6189
# top     http://www.linkedin.com/in/mukesh-dev-48750218
# freq                                                 8
#
#                                                             Campaign Name  \
# count                                                                6045
# unique                                                                  1
# top     Employee Size 11 - 100 (Founded Year 2020 - 2024)(Funded Company)
# ...

# %%
df3.isnull().sum()
# Out:
# Company Name            0
# Name                    0
# Tittle                  0
# Website              6207
# Company Linkedin     6237
# Linkedin URL         1829
# Campaign Name        3848
# Email Status         6118
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# np.int64(1225)

# %%
df3.isnull().sum() / len(df3)* 100
# Out:
# Company Name          0.000000
# Name                  0.000000
# Tittle                0.000000
# Website              62.741332
# Company Linkedin     63.044577
# Linkedin URL         18.487820
# Campaign Name        38.896189
# Email Status         61.841706
# dtype: float64

# %%
df3['Linkedin URL'] = df3['Linkedin URL'].fillna('Not Available')

# %%
df3.isnull().sum()
# Out:
# Company Name            0
# Name                    0
# Tittle                  0
# Website              6207
# Company Linkedin     6237
# Linkedin URL            0
# Campaign Name        3848
# Email Status         6118
# dtype: int64

# %%
df3.columns
# Out:
# Index(['Company Name', 'Name', 'Tittle', 'Website', 'Company Linkedin ',
#        'Linkedin URL', 'Campaign Name', 'Email Status'],
#       dtype='object')

# %%
df3['Campaign Name'] = df3['Campaign Name'].fillna(df3['Campaign Name'].mode()[0])

df3['Email Status'] = df3['Email Status'].fillna(df3['Email Status'].mode()[0])

# %%
df3.isnull().sum()
# Out:
# Company Name            0
# Name                    0
# Tittle                  0
# Website              6207
# Company Linkedin     6237
# Linkedin URL            0
# Campaign Name           0
# Email Status            0
# dtype: int64

# %%
df3.isnull().sum() / len(df3)* 100
# Out:
# Company Name          0.000000
# Name                  0.000000
# Tittle                0.000000
# Website              62.741332
# Company Linkedin     63.044577
# Linkedin URL          0.000000
# Campaign Name         0.000000
# Email Status          0.000000
# dtype: float64

# %%
df3 = df3.drop(columns=['Website', 'Company Linkedin '])

# %%
df3.isnull().sum()
# Out:
# Company Name     0
# Name             0
# Tittle           0
# Linkedin URL     0
# Campaign Name    0
# Email Status     0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# np.int64(1785)

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.to_csv('campaign_email_data.csv', index=False)

# %%
df4 = pd.read_csv("/content/DA Test- Linkedin Campaign Process - LinkedinMasterDataBase (1).csv")
df4.head()
# Out:
#   Account Status Company Name               Name  \
# 0       Inactive       13SQFT        Alok Bansal
# 1         Active           1K    Abhishek Halder
# 2         Active           1K      Sachin Sharma
# 3         Active  2070 Health    Pankaj Jethwani
# 4       Inactive   5C Network  Kalyan Sivasailam
#
#                                    Personal Linkedin  \
# 0    http://www.linkedin.com/in/alok-bansal-87162637
# 1          http://www.linkedin.com/in/halderabhishek
# 2  http://www.linkedin.com/in/sachin-sharma-7b11a515
# 3              https://www.linkedin.com/in/pankajsj/
# 4      https://www.linkedin.com/in/kalyansivasailam/
#
#                      Website Company Linkedin              Designation  \
# 0     http://www.13sqft.com/              NaN                  Founder
# 1    http://www.niyotail.com              NaN                  Founder
# 2    http://www.niyotail.com              NaN                  Founder
# ...

# %%
df4.columns
# Out:
# Index(['Account Status', 'Company Name', 'Name', 'Personal Linkedin',
#        'Website', 'Company Linkedin', 'Designation', 'Linkedin Status',
#        'linkedin account ', 'Date', 'Linkedin Invite', 'Date.1', 'Sequence 1',
#        'Date.2', 'Sequence 2', 'Date.3', 'Sequence 3', 'Date.4', 'Sequence 4',
#        'Date.5'],
#       dtype='object')

# %%
df4.shape
# Out:
# (6742, 20)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6742 entries, 0 to 6741
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Account Status     6742 non-null   object
#  1   Company Name       6740 non-null   object
#  2   Name               6708 non-null   object
#  3   Personal Linkedin  6681 non-null   object
#  4   Website            5511 non-null   object
#  5   Company Linkedin   4198 non-null   object
#  6   Designation        6669 non-null   object
#  7   Linkedin Status    4971 non-null   object
#  8   linkedin account   4923 non-null   object
#  9   Date               4781 non-null   object
#  10  Linkedin Invite    4776 non-null   object
#  11  Date.1             1918 non-null   object
#  12  Sequence 1         2288 non-null   object
#  13  Date.2             925 non-null    object
#  14  Sequence 2         2192 non-null   object
#  15  Date.3             2057 non-null   object
# ...

# %%
df4.describe(include='all')
# Out:
#        Account Status Company Name           Name  \
# count            6742         6740           6708
# unique              2         3848           6333
# top            Active       Friend  Suyash Khemka
# freq             5825           40              7
#
#                               Personal Linkedin Website Company Linkedin  \
# count                                      6681    5511             4198
# unique                                     6541    3217             2364
# top     http://www.linkedin.com/in/suyashkhemka   #REF!            #REF!
# freq                                          6     646              658
#
#        Designation              Linkedin Status linkedin account   \
# count         6669                         4971              4923
# unique        1462                           14                46
# top        Founder  Started - Linkedin Sequence                Kr
# freq           746                         4046              1302
#
# ...

# %%
df4.isnull().sum()
# Out:
# Account Status          0
# Company Name            2
# Name                   34
# Personal Linkedin      61
# Website              1231
# Company Linkedin     2544
# Designation            73
# Linkedin Status      1771
# linkedin account     1819
# Date                 1961
# Linkedin Invite      1966
# Date.1               4824
# Sequence 1           4454
# Date.2               5817
# Sequence 2           4550
# Date.3               4685
# Sequence 3           4602
# Date.4               5006
# Sequence 4           5009
# Date.5               6725
# dtype: int64

# %%
df4.duplicated().sum()
# Out:
# np.int64(63)

# %%
df4.isnull().sum() / len(df4)* 100
# Out:
# Account Status        0.000000
# Company Name          0.029665
# Name                  0.504301
# Personal Linkedin     0.904776
# Website              18.258677
# Company Linkedin     37.733610
# Designation           1.082765
# Linkedin Status      26.268170
# linkedin account     26.980125
# Date                 29.086325
# Linkedin Invite      29.160487
# Date.1               71.551468
# Sequence 1           66.063483
# Date.2               86.280036
# Sequence 2           67.487392
# Date.3               69.489766
# Sequence 3           68.258677
# Date.4               74.250964
# Sequence 4           74.295461
# Date.5               99.747849
# dtype: float64

# %%
df4 = df4.drop(columns=['Date.5'])

# %%
df4['Personal Linkedin'] = df4.apply(
    lambda row: row['Personal Linkedin'] if pd.notna(row['Personal Linkedin'])
    else f"http://www.linkedin.com/in/{str(row['Name']).replace(' ', '-').lower()}", axis=1)

# %%
df4.isnull().sum()
# Out:
# Account Status          0
# Company Name            2
# Name                   34
# Personal Linkedin       0
# Website              1231
# Company Linkedin     2544
# Designation            73
# Linkedin Status      1771
# linkedin account     1819
# Date                 1961
# Linkedin Invite      1966
# Date.1               4824
# Sequence 1           4454
# Date.2               5817
# Sequence 2           4550
# Date.3               4685
# Sequence 3           4602
# Date.4               5006
# Sequence 4           5009
# dtype: int64

# %%
df4 = df4.drop(columns=['Date.1', 'Sequence 1', 'Date.2', 'Sequence 2', 'Date.3', 'Sequence 3', 'Date.4', 'Sequence 4'])

# %%
df4.isnull().sum()
# Out:
# Account Status          0
# Company Name            2
# Name                   34
# Personal Linkedin       0
# Website              1231
# Company Linkedin     2544
# Designation            73
# Linkedin Status      1771
# linkedin account     1819
# Date                 1961
# Linkedin Invite      1966
# dtype: int64

# %%
df4.isnull().sum() / len(df4)* 100
# Out:
# Account Status        0.000000
# Company Name          0.029665
# Name                  0.504301
# Personal Linkedin     0.000000
# Website              18.258677
# Company Linkedin     37.733610
# Designation           1.082765
# Linkedin Status      26.268170
# linkedin account     26.980125
# Date                 29.086325
# Linkedin Invite      29.160487
# dtype: float64

# %%
df4['Date'] = pd.to_datetime(df4['Date'], errors='coerce')
df4['Date'] = df4['Date'].ffill()

# %%
df4.isnull().sum() / len(df4)*100
# Out:
# Account Status        0.000000
# Company Name          0.029665
# Name                  0.504301
# Personal Linkedin     0.000000
# Website              18.258677
# Company Linkedin     37.733610
# Designation           1.082765
# Linkedin Status      26.268170
# linkedin account     26.980125
# Date                  0.000000
# Linkedin Invite      29.160487
# dtype: float64

# %%
df4.dropna(inplace=True)

# %%
df4.isnull().sum()
# Out:
# Account Status       0
# Company Name         0
# Name                 0
# Personal Linkedin    0
# Website              0
# Company Linkedin     0
# Designation          0
# Linkedin Status      0
# linkedin account     0
# Date                 0
# Linkedin Invite      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df4.to_csv("linkedin.csv",index=False)

# %%
df5 = pd.read_csv('/content/DA Test- Whats app Campaign Process - New Whatsapp (1).csv',encoding='utf-8')
df5.head()
# Out:
#      Status Priority         Company             Name         Tittle  \
# 0    Active      NaN  Accio Robotics     Tuhin Sharma      CoFounder
# 1  Inactive      NaN    Alt Mobility       Anuj Gupta  CoFounder&CBO
# 2  Inactive      NaN    Alt Mobility        Dev Arora  Cofounder&CEO
# 3  Inactive      NaN           Ambak   Pranav Khattar      CoFounder
# 4  Inactive      NaN           Ambak  Raghuveer Malik      CoFounder
#
#                           Website  \
# 0  https://www.acciorobotics.com/
# 1    https://www.altmobility.com/
# 2    https://www.altmobility.com/
# 3          https://www.ambak.com/
# 4          https://www.ambak.com/
#
#                                  Company Linkedin  \
# 0  https://www.linkedin.com/company/acciorobotics
# 1    https://www.linkedin.com/company/altmobility
# 2    https://www.linkedin.com/company/altmobility
# 3  https://www.linkedin.com/company/ambakofficial
# 4  https://www.linkedin.com/company/ambakofficial
#
# ...

# %%
df5.columns
# Out:
# Index(['Status', 'Priority', 'Company', 'Name', 'Tittle', 'Website',
#        'Company Linkedin', 'LinkedinURL', 'Duplicate', 'NumberDuplicate',
#        'MessageFrom', 'WhatsappStatus', 'Notes', 'Sundaycampaign',
#        'WhatsappSequence1', 'Time', 'WhatsappSequence2', 'Time.1',
#        'WhatsappSequence3', 'Time.2', 'WhatsappSequence4', 'Time.3',
#        'WhatsappSequence5', 'Time.4', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df5.shape
# Out:
# (6492, 26)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6492 entries, 0 to 6491
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Status             6492 non-null   object
#  1   Priority           234 non-null    object
#  2   Company            6492 non-null   object
#  3   Name               6492 non-null   object
#  4   Tittle             6441 non-null   object
#  5   Website            3493 non-null   object
#  6   Company Linkedin   3462 non-null   object
#  7   LinkedinURL        5779 non-null   object
#  8   Duplicate          6492 non-null   object
#  9   NumberDuplicate    6492 non-null   object
#  10  MessageFrom        3793 non-null   object
#  11  WhatsappStatus     3834 non-null   object
#  12  Notes              97 non-null     object
#  13  Sundaycampaign     1418 non-null   object
#  14  WhatsappSequence1  3335 non-null   object
#  15  Time               2667 non-null   object
# ...

# %%
df5.describe(include='all')
# Out:
#         Status    Priority            Company          Name     Tittle  \
# count     6492         234               6492          6492       6441
# unique       2          10               2739          4451       1265
# top     Active  2025Funded  Arcatron Mobility  Dewaj Baruah  CoFounder
# freq      5429         162                 47            47       1353
#
#                            Website  \
# count                         3493
# unique                        2208
# top     http://www.lendingkart.com
# freq                            10
#
#                                     Company Linkedin  \
# count                                           3462
# unique                                          2023
# top     https://www.linkedin.com/company/lendingkart
# freq                                              10
#
#                                   LinkedinURL Duplicate NumberDuplicate  \
# count                                    5779      6492            6492
# ...

# %%
df5.isnull().sum()
# Out:
# Status                  0
# Priority             6258
# Company                 0
# Name                    0
# Tittle                 51
# Website              2999
# Company Linkedin     3030
# LinkedinURL           713
# Duplicate               0
# NumberDuplicate         0
# MessageFrom          2699
# WhatsappStatus       2658
# Notes                6395
# Sundaycampaign       5074
# WhatsappSequence1    3157
# Time                 3825
# WhatsappSequence2    4310
# Time.1               4353
# WhatsappSequence3    5354
# Time.2               5354
# WhatsappSequence4    6118
# Time.3               6118
# WhatsappSequence5    6302
# Time.4               6302
# Unnamed: 24             0
# Unnamed: 25             0
# dtype: int64

# %%
df5.duplicated().sum()
# Out:
# np.int64(83)

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Priority             96.395564
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website              46.195317
# Company Linkedin     46.672828
# LinkedinURL          10.982748
# Duplicate             0.000000
# NumberDuplicate       0.000000
# MessageFrom          41.574245
# WhatsappStatus       40.942699
# Notes                98.505853
# Sundaycampaign       78.157733
# WhatsappSequence1    48.629082
# Time                 58.918669
# WhatsappSequence2    66.389402
# Time.1               67.051756
# WhatsappSequence3    82.470733
# Time.2               82.470733
# WhatsappSequence4    94.239063
# Time.3               94.239063
# WhatsappSequence5    97.073321
# Time.4               97.073321
# Unnamed: 24           0.000000
# Unnamed: 25           0.000000
# dtype: float64

# %%
df5['LinkedinURL'] = df5.apply(
    lambda row: row['LinkedinURL'] if pd.notna(row['LinkedinURL'])
    else f"http://www.linkedin.com/in/{str(row['Name']).replace(' ', '-').lower()}", axis=1)

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Priority             96.395564
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website              46.195317
# Company Linkedin     46.672828
# LinkedinURL           0.000000
# Duplicate             0.000000
# NumberDuplicate       0.000000
# MessageFrom          41.574245
# WhatsappStatus       40.942699
# Notes                98.505853
# Sundaycampaign       78.157733
# WhatsappSequence1    48.629082
# Time                 58.918669
# WhatsappSequence2    66.389402
# Time.1               67.051756
# WhatsappSequence3    82.470733
# Time.2               82.470733
# WhatsappSequence4    94.239063
# Time.3               94.239063
# WhatsappSequence5    97.073321
# Time.4               97.073321
# Unnamed: 24           0.000000
# Unnamed: 25           0.000000
# dtype: float64

# %%
df5['Company Linkedin'] = df5.apply(
    lambda row: row['Company Linkedin'] if pd.notna(row['Company Linkedin'])
    else f"https://www.linkedin.com/company/{str(row['Company']).replace(' ', '-').lower()}", axis=1)

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Priority             96.395564
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website              46.195317
# Company Linkedin      0.000000
# LinkedinURL           0.000000
# Duplicate             0.000000
# NumberDuplicate       0.000000
# MessageFrom          41.574245
# WhatsappStatus       40.942699
# Notes                98.505853
# Sundaycampaign       78.157733
# WhatsappSequence1    48.629082
# Time                 58.918669
# WhatsappSequence2    66.389402
# Time.1               67.051756
# WhatsappSequence3    82.470733
# Time.2               82.470733
# WhatsappSequence4    94.239063
# Time.3               94.239063
# WhatsappSequence5    97.073321
# Time.4               97.073321
# Unnamed: 24           0.000000
# Unnamed: 25           0.000000
# dtype: float64

# %%
df5['Website'] = df5.apply(
    lambda row: row['Website'] if pd.notna(row['Website'])
    else f"https://www.{str(row['Company']).replace(' ', '').lower()}.com", axis=1)

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Priority             96.395564
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website               0.000000
# Company Linkedin      0.000000
# LinkedinURL           0.000000
# Duplicate             0.000000
# NumberDuplicate       0.000000
# MessageFrom          41.574245
# WhatsappStatus       40.942699
# Notes                98.505853
# Sundaycampaign       78.157733
# WhatsappSequence1    48.629082
# Time                 58.918669
# WhatsappSequence2    66.389402
# Time.1               67.051756
# WhatsappSequence3    82.470733
# Time.2               82.470733
# WhatsappSequence4    94.239063
# Time.3               94.239063
# WhatsappSequence5    97.073321
# Time.4               97.073321
# Unnamed: 24           0.000000
# Unnamed: 25           0.000000
# dtype: float64

# %%
columns_to_fill = ['WhatsappSequence1', 'Time', 'WhatsappSequence2', 'Time.1',
       'WhatsappSequence3', 'Time.2', 'WhatsappSequence4', 'Time.3',
       'WhatsappSequence5', 'Time.4']
df5[columns_to_fill] = df5[columns_to_fill].ffill(axis=1)

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Priority             96.395564
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website               0.000000
# Company Linkedin      0.000000
# LinkedinURL           0.000000
# Duplicate             0.000000
# NumberDuplicate       0.000000
# MessageFrom          41.574245
# WhatsappStatus       40.942699
# Notes                98.505853
# Sundaycampaign       78.157733
# WhatsappSequence1    48.629082
# Time                 48.629082
# WhatsappSequence2    48.582871
# Time.1               48.582871
# WhatsappSequence3    48.567468
# Time.2               48.567468
# WhatsappSequence4    48.567468
# Time.3               48.567468
# WhatsappSequence5    48.567468
# Time.4               48.567468
# Unnamed: 24           0.000000
# Unnamed: 25           0.000000
# dtype: float64

# %%
df5.columns
# Out:
# Index(['Status', 'Priority', 'Company', 'Name', 'Tittle', 'Website',
#        'Company Linkedin', 'LinkedinURL', 'Duplicate', 'NumberDuplicate',
#        'MessageFrom', 'WhatsappStatus', 'Notes', 'Sundaycampaign',
#        'WhatsappSequence1', 'Time', 'WhatsappSequence2', 'Time.1',
#        'WhatsappSequence3', 'Time.2', 'WhatsappSequence4', 'Time.3',
#        'WhatsappSequence5', 'Time.4', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
columns_to_drop = ['Priority', 'Unnamed: 24', 'Unnamed: 25', 'MessageFrom', 'Notes']
df5 = df5.drop(columns=columns_to_drop)

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website               0.000000
# Company Linkedin      0.000000
# LinkedinURL           0.000000
# Duplicate             0.000000
# NumberDuplicate       0.000000
# WhatsappStatus       40.942699
# Sundaycampaign       78.157733
# WhatsappSequence1    48.629082
# Time                 48.629082
# WhatsappSequence2    48.582871
# Time.1               48.582871
# WhatsappSequence3    48.567468
# Time.2               48.567468
# WhatsappSequence4    48.567468
# Time.3               48.567468
# WhatsappSequence5    48.567468
# Time.4               48.567468
# dtype: float64

# %%
df5['WhatsappStatus'] = df5['WhatsappStatus'].fillna(df5['WhatsappStatus'].mode()[0])
df5['Sundaycampaign'] = df5['Sundaycampaign'].fillna(df5['Sundaycampaign'].mode()[0])

# %%
df5.isnull().sum() / len(df5)* 100
# Out:
# Status                0.000000
# Company               0.000000
# Name                  0.000000
# Tittle                0.785582
# Website               0.000000
# Company Linkedin      0.000000
# LinkedinURL           0.000000
# Duplicate             0.000000
# NumberDuplicate       0.000000
# WhatsappStatus        0.000000
# Sundaycampaign        0.000000
# WhatsappSequence1    48.629082
# Time                 48.629082
# WhatsappSequence2    48.582871
# Time.1               48.582871
# WhatsappSequence3    48.567468
# Time.2               48.567468
# WhatsappSequence4    48.567468
# Time.3               48.567468
# WhatsappSequence5    48.567468
# Time.4               48.567468
# dtype: float64

# %%
df5.dropna(inplace=True)

# %%
df5.isnull().sum()
# Out:
# Status               0
# Company              0
# Name                 0
# Tittle               0
# Website              0
# Company Linkedin     0
# LinkedinURL          0
# Duplicate            0
# NumberDuplicate      0
# WhatsappStatus       0
# Sundaycampaign       0
# WhatsappSequence1    0
# Time                 0
# WhatsappSequence2    0
# Time.1               0
# WhatsappSequence3    0
# Time.2               0
# WhatsappSequence4    0
# Time.3               0
# WhatsappSequence5    0
# Time.4               0
# dtype: int64

# %%
df5.duplicated().sum()
# Out:
# np.int64(0)

# %%
df5.to_csv("whatsapp.csv", index=False)
